# %%
import pandas as pd
import numpy as np

# %%
results_df = pd.read_csv("/Users/rohitsuresh/Documents/IISC/VCM_shapely/data/results/synergy_20250814_102805/results.csv")

# %%
results_df.head()
# Out:
#    num_farmers farmer_id  farmer_shapley  actual_area   avg_shapley  \
# 0            2    F00118        0.000000         2.20      0.000000
# 1            2    F00200        0.000000         2.20      0.000000
# 2            3    F00118     8204.865027         9.38  14474.761256
# 3            3    F00200     9312.076460         9.38  14474.761256
# 4            3    F00159    25907.342280         9.38  14474.761256
#
#    core_stable  blocking_probability  is_convex  convexity_violation_rate  \
# 0         True                   0.0       True                  0.000000
# 1         True                   0.0       True                  0.000000
# 2         True                   0.0      False                  0.027778
# 3         True                   0.0      False                  0.027778
# 4         True                   0.0      False                  0.027778
#
#    aggregator_profit        roi  total_project_profit  run_id fpo_id
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

selected_farmer = "F00200"
farmer_df = results_df[results_df['farmer_id'] == selected_farmer]

# %%
farmer_df
# Out:
#     num_farmers farmer_id  farmer_shapley  actual_area   avg_shapley  \
# 1             2    F00200        0.000000         2.20      0.000000
# 3             3    F00200     9312.076460         9.38  14474.761256
# 6             4    F00200     9005.648289        10.94  14806.020752
# 10            5    F00200     9268.622589        12.53  15349.156212
# 15            6    F00200     9773.496134        15.27  16812.838236
# 21            7    F00200    10255.179828        19.95  18221.499438
# 28            8    F00200    10293.440861        22.05  17374.355275
# 36            9    F00200    10464.183504        24.12  17562.379857
# 45           10    F00200    11015.290313        30.67  20376.223811
#
#     core_stable  blocking_probability  is_convex  convexity_violation_rate  \
# 1          True                   0.0       True                  0.000000
# 3          True                   0.0      False                  0.027778
# ...

# %%
plt.figure(figsize=(10,6))
sns.lineplot(
    data=farmer_df,
    x='num_farmers',
    y='farmer_shapley',
    hue='run_id',  
    palette='tab10'
)
plt.title(f"Payoff Trend for Farmer {selected_farmer}", fontsize=16, weight='bold')
plt.xlabel("Number of Farmers in Coalition")
plt.ylabel("Payoff (INR)")
plt.axhline(0, color='gray', linestyle='--', linewidth=1)
plt.legend(title="Run ID", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
plt.savefig(f"/Users/rohitsuresh/Documents/IISC/VCM_shapely/data/results/sequential_growth_20250807_152420/farmer_{selected_farmer}_payoff_trend.png")
plt.close()

# %%
df["shapley_per_acre"] = df["farmer_shapley"] / df["actual_area"]
df_farmer = df[df["farmer_id"] == "F00200"].sort_values("num_farmers")

plt.plot(df_farmer["num_farmers"], df_farmer["shapley_per_acre"], marker='o')
plt.title("Farmer F00200: Payoff per Acre vs Coalition Size")
plt.xlabel("Coalition Size")
plt.ylabel("Payoff per Acre (₹)")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 df["shapley_per_acre"] = df["farmer_shapley"] / df["actual_area"]
#       2 df_farmer = df[df["farmer_id"] == "F00200"].sort_values("num_farmers")
#       4 plt.plot(df_farmer["num_farmers"], df_farmer["shapley_per_acre"], marker='o')
#
# NameError: name 'df' is not defined
